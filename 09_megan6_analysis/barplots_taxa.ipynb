# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./420_transcrips_m2_outfmt6-ex_sum.txt", sep="\t")


barplots = sns.barplot(data=data, y="tax.id", x="count")
plt.xlabel("Putative AMPs")
plt.ylabel("Related taxa")
# Out:
# Text(0, 0.5, 'Related taxa')

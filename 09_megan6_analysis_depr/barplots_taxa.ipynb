# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./420_transcrips_m2_outfmt6-ex_sum_filt.txt", sep="\t")

barplots = sns.barplot(data=data, y="tax.id", x="count")
plt.xlabel("Number of AMPs")
plt.ylabel("Taxa")
plt.tight_layout()
plt.savefig("./megan_taxa_sum_filt.svg")

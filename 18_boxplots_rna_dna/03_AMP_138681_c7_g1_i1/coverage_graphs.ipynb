# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# # Load the data
# df = pd.read_csv('./coverage_per_base_AMP_138200_c2_g1_i1.tsv', sep='\t')

# # df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Coverage per base Phocaeicola dorei strain 2 plasmid')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=72152, color='red', linestyle='--')
# plt.axvline(x=71409, color='red', linestyle='--')
# plt.savefig('coverage_per_base_AMP_138200_c2_g1_i1.png')
# plt.show()

# cobertura del genoma en la bacteria thetaiotaomicron

# %%
# df = pd.read_csv('./coverage_per_base_AMP_138200_c2_g1_i1.tsv', sep='\t')

# # df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.xlim(71000, 73000)
# plt.title('Coverage per base Phocaeicola dorei strain 2 plasmid')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=72152, color='red', linestyle='--')
# plt.axvline(x=71409, color='red', linestyle='--')
# # plt.savefig('coverage_per_base_AMP_138200_c2_g1_i1_zoom.png')
# plt.show()

# %%
# # Load the data
# df = pd.read_csv('./coverage_per_base_AMP_143020_c3_g1_i1.tsv', sep='\t')

# # df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.xlim(19500, 19700)
# plt.title('Coverage per base Caudoviricetes sp. isolate ctJ1L4')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=19543, color='red', linestyle='--')
# plt.axvline(x=19642, color='red', linestyle='--')
# plt.savefig('coverage_per_base_AMP_143020_c3_g1_i1_zoom.png')
# plt.show()

# %%
# # Load the data
# df = pd.read_csv('./coverage_per_base_AMP_138681_c7_g1_i1.tsv', sep='\t')

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Coverage per base Caudoviricetes sp. isolate ctlNO7')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=116, color='red', linestyle='--')
# plt.axvline(x=443, color='red', linestyle='--')
# plt.savefig('coverage_per_base_AMP_138681_c7_g1_i1.png')
# plt.show()

# #
# sns.lineplot(data=df, x='base', y='coverage')
# plt.xlim(1, 500)
# plt.title('Coverage per base Caudoviricetes sp. isolate ctlNO7')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=116, color='red', linestyle='--')
# plt.axvline(x=443, color='red', linestyle='--')
# plt.savefig('coverage_per_base_AMP_138681_c7_g1_i1_zoom.png')
# plt.show()

# # log10
# df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Coverage per base Caudoviricetes sp. isolate ctlNO7')
# plt.xlabel('Base')
# plt.ylabel('Coverage (log10)')
# plt.axvline(x=116, color='red', linestyle='--')
# plt.axvline(x=443, color='red', linestyle='--')
# plt.savefig('coverage_per_base_AMP_138681_c7_g1_i1_log10.png')
# plt.show()
# Out:
# /Users/luigui/miniconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# # Load the data
# df = pd.read_csv('./coverage_per_base_scaffold_11136.tsv', sep='\t')

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Scaffold 11136\n Total coverage with Viral DNA reads: 100%')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136.png')
# plt.savefig('coverage_per_base_scaffold_11136.svg')
# plt.show()

# #
# sns.lineplot(data=df, x='base', y='coverage')
# plt.xlim(3800, 4200)
# plt.title('Scaffold 11136\n Total coverage with Viral DNA reads: 100%')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136_zoom.png')
# plt.savefig('coverage_per_base_scaffold_11136_zoom.svg')
# plt.show()

# # log10
# df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Scaffold 11136\n Total coverage with Viral DNA reads: 100%')
# plt.xlabel('Base')
# plt.ylabel('Coverage (log10)')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136_log10.png')
# plt.savefig('coverage_per_base_scaffold_11136_log10.svg')
# plt.show()

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# # Load the data
# df = pd.read_csv('./coverage_per_base_scaffold_11136_rna.tsv', sep='\t')

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Scaffold 11136\n Total coverage with RNA reads: 46%')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136_rna.png')
# plt.savefig('coverage_per_base_scaffold_11136_rna.svg')
# plt.show()

# #
# sns.lineplot(data=df, x='base', y='coverage')
# plt.xlim(3800, 4200)
# plt.title('Scaffold 11136\n Total coverage with RNA reads: 46%')
# plt.xlabel('Base')
# plt.ylabel('Coverage')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136_zoom_rna.png')
# plt.savefig('coverage_per_base_scaffold_11136_zoom_rna.svg')
# plt.show()

# # log10
# df['coverage'] = np.log(df['coverage'])

# sns.lineplot(data=df, x='base', y='coverage')
# plt.title('Scaffold 11136\n Total coverage with RNA reads: 46%')
# plt.xlabel('Base')
# plt.ylabel('Coverage (log10)')
# plt.axvline(x=4056, color='red', linestyle='--')
# plt.axvline(x=4158, color='red', linestyle='--')
# plt.savefig('coverage_per_base_scaffold_11136_log10_rna.png')
# plt.savefig('coverage_per_base_scaffold_11136_log10_rna.svg')
# plt.show()
# Out:
# /Users/luigui/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
